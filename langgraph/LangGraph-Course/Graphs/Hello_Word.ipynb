# %% [markdown]
# # Graph I
# Our first LangGraph graph!

# %%
# 导入类型提示和LangGraph状态图框架
from typing import Dict, TypedDict
from langgraph.graph import StateGraph # framework that helps you design and manage the flow of tasks in your application using a graph structure
# StateGraph是LangGraph的核心，用于设计和管理应用程序中的任务流

# %%
# We now create an AgentState - shared data structure that keeps track of information as your application runs. 
# 创建AgentState - 在应用运行过程中跟踪信息的共享数据结构

# 定义状态模式
class AgentState(TypedDict): # Our state schema
    message : str  # 消息字段


# 定义问候节点函数
def greeting_node(state: AgentState) -> AgentState:
    """Simple node that adds a greeting message to the state"""

    # 在用户名前后添加问候语
    state['message'] = "Hey " + state["message"] + ", how is your day going?"

    return state

# %%
# 创建状态图实例
graph = StateGraph(AgentState)

# 添加问候节点
graph.add_node("greeter", greeting_node)

# 设置入口点和终止点
graph.set_entry_point("greeter")
graph.set_finish_point("greeter")

# 编译图，生成可执行的应用
app = graph.compile()

# %%
# 可视化图的结构
from IPython.display import Image, display
display(Image(app.get_graph().draw_mermaid_png()))

# %%
# 调用图，传入初始消息（用户名）
result = app.invoke({"message": "Bob"})

# %%
# 输出结果中的message字段
result["message"]
