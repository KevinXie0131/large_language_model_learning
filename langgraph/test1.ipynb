# %%
# 导入预构建的 ReAct Agent 创建函数
from langgraph.prebuilt import create_react_agent

# 创建一个 ReAct Agent 实例
agent = create_react_agent(
    model=model,        # 指定使用的语言模型
    tools=[],           # 工具列表（此处为空，不使用外部工具）
    prompt="You are a helpful assistant",  # 系统提示词
)

# 调用 Agent 并传入用户消息
agent.invoke({"messages":[{"role":"user","content":"你是谁？能帮我解决什么问题？"}]})
