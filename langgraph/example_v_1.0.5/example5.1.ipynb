# %%
# !uv tool install langgraph-cli
# Out:
# Resolved 13 packages in 622ms
# Prepared 3 packages in 335ms
# Installed 13 packages in 429ms
#  + anyio==4.13.0
#  + certifi==2026.2.25
#  + click==8.3.2
#  + colorama==0.4.6
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + idna==3.11
#  + langgraph-cli==0.4.21
#  + langgraph-sdk==0.3.13
#  + orjson==3.11.8
#  + pathspec==1.0.4
#  + python-dotenv==1.2.2
# Installed 1 executable: langgraph

# %%
# !uv tool list
# Out:
# langgraph-cli v0.4.21
# - langgraph

# %%
# !langgraph --help
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\KevinX\.local\bin\langgraph.exe\__main__.py", line 4, in <module>
#     from langgraph_cli.cli import cli
#   File "C:\Users\KevinX\AppData\Roaming\uv\tools\langgraph-cli\Lib\site-packages\langgraph_cli\cli.py", line 12, in <module>
#     import langgraph_cli.config
#   File "C:\Users\KevinX\AppData\Roaming\uv\tools\langgraph-cli\Lib\site-packages\langgraph_cli\config.py", line 13, in <module>
#     from langgraph_cli.schemas import Config, Distros
#   File "C:\Users\KevinX\AppData\Roaming\uv\tools\langgraph-cli\Lib\site-packages\langgraph_cli\schemas.py", line 3, in <module>
#     from typing_extensions import Required
# ModuleNotFoundError: No module named 'typing_extensions'

# %% [markdown]
# ![image.png](attachment:9b14442e-d0be-4b27-b742-411628fbe364.png)

# %%
# !langgraph new demo-agent --template new-langgraph-project-python

# %%
# !uv run langgraph dev

# %% [markdown]
# 备用方案：使用 Cloudflare Tunnel
#
# 如果上述方法无效，可使用隧道绕过本地网络限制

# %%
# 安装/更新 CLI
# !pip install -U langgraph-cli>=0.2.6
# 启动带隧道的开发服务器
# !langgraph dev --tunnel

# %% [markdown]
# 命令会输出一个隧道 URL（如 https://xxx.trycloudflare.com），然后：
#
# 打开 https://smith.langchain.com/studio/
#
# 点击 "Connect to a local server"
#
# 粘贴隧道 URL 并添加到 Allowed Origins
#
# 点击 Connect
